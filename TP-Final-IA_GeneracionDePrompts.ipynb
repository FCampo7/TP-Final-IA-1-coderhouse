# %% [markdown]
# # Trabajo Final: IA Gamificada para Niños con TDAH: Aprender Jugando con Prompt Engineering
#
# ## Resumen
#
# Se propone el diseño de un sistema de generación de contenido educativo gamificado mediante prompt engineering, orientado a niños de entre 8 y 12 años con Trastorno por Déficit de Atención e Hiperactividad (TDAH).
# El objetivo es transformar lecciones escolares en experiencias interactivas, con misiones, preguntas de opción múltiple y retroalimentación positiva. Se implementan prompts adaptados para la API de Gemini, garantizando la posibilidad de producir salidas estructuradas en JSON, lo que facilita el desarrollo de aplicaciones interactivas. Asimismo, se incluyen ejemplos de prompts para generar imágenes educativas que complementen las historias.
#
# ## Índice
#
# 1. Introducción
# 2. Objetivos
# 3. Metodología
# 4. Herramientas y Tecnologías
# 5. Viabilidad
# 6. Implementación
#
# ## 1. Introducción
#
# El Trastorno por Déficit de Atención e Hiperactividad (TDAH) afecta la forma en que muchos niños aprenden y procesan la información. En particular, entre los 8 y 12 años, la concentración sostenida y la memorización de conceptos abstractos resultan muy difíciles.
# En contextos educativos tradicionales, los niños con TDAH suelen perder la motivación rápidamente, lo que deriva en frustración, bajo rendimiento y una percepción negativa del estudio. Es un problema relevante porque impacta no solo en lo académico, sino también en la autoestima y en la integración social de los niños.
#
# ## 2. Objetivos
#
# * Diseñar prompts capaces de transformar contenido educativo en narrativas gamificadas.
# * Incorporar preguntas de opción múltiple con retroalimentación positiva inmediata.
# * Definir un formato estructurado de salida (JSON) para facilitar la integración con aplicaciones.
#
# ## 3. Metodología
#
# 1. **Diseño de prompts:**
#    * Texto → Texto: generar historias interactivas, preguntas y feedback en JSON.
#    * Texto → Imagen: generar personajes, escenarios y recompensas visuales.
# 2. **Pruebas de salida:** validar que los modelos devuelvan JSON válido y narrativas adaptadas a la edad objetivo.
# 3. **Iteración y ajuste:** modificar los prompts para mejorar la calidad de la narrativa y la claridad de las preguntas.
#
# ## 4. Herramientas y Tecnologías
#
# * Python como lenguaje de implementación.
# * Google Gemini API para generación de texto y, opcionalmente, imágenes.
# * Gestión de variables de entorno con .env para proteger la API Key.
# * Bibliotecas: google-genai, dotenv.
#
# ## 5. Viabilidad:
#
# * Técnica:
#   * Totalmente viable, tanto Gemini como chatGPT pueden realizar una respuesta en formato json, solo requiere un mínimo de procesamiento de texto previo ya que lo devuelve dentro de un formato markdown.
# * Económicamente:
#   * La generación de imágenes es más costosa, pero se puede realizar una demostración técnica utilizando generadores gratuitos como leonardo.ai o Gemini en su versión web.
#
# ## 6. Implementación
#
# ### Requerimientos
#
# Para poder ejecutarlo debe obtener una free api key de Gemini y crear un .env en la carpeta raíz con el siguiente código
#
# `API_KEY="Tu api key"`
#
# Antes de correrlo debe ejecutar el siguiente comando en la carpeta raíz
#
# `pip install -r "requirements.txt"`
#
# ### Código

# %% [markdown]
# ### Carga de la API KEY desde el archivo .env

# %%
from dotenv import load_dotenv
import os

load_dotenv(".env")

mi_api_key = os.getenv("API_KEY")
if not mi_api_key:
    raise ValueError("API_KEY environment variable is not set.")

# %% [markdown]
# ### Ejecución del prompt con las palabras claves a ingresar
#
# Se diseñaron prompts parametrizados que aceptan variables, para poder cambiar el tema de la asignatura, la ambientación de la misión, la edad del niño y el tono de respuesta de la IA.
#
# También se pide que responda en formato json para facilitar la creación de un software de preguntas y respuestas interactivas.
#
# El prompt de las imágenes también fue parametrizado para que se pueda cambiar el personaje, el estilo de la imagen, la edad del niño al cual está dirigido y la pregunta que se desea ilustrar para contextualizar la misma.
#
# #### _Prompt para obtener preguntas estilo múltiple Choice:_
#
# Convierte esta lección sobre {tema} en una misión interactiva estilo {ambientacion}.
# La historia debe estar dirigida a un niño de {edad} años con TDAH.
# Incluye preguntas de opción múltiple, respuestas con feedback positivo, y un tono {tono}.
#
# Devuelve la respuesta en JSON válido con el siguiente formato:
# ```json
# {{
#   "historia": "texto breve con la narrativa gamificada",
#   "preguntas": [
#     {{
#       "pregunta": "string",
#       "opciones": ["string", "string", "string"],
#       "respuesta_correcta": "string",
#       "feedback": {{
#         "correcto": "string",
#         "incorrecto": "string"
#       }}
#     }}
#   ]
# }}
# ```
#
# #### _Prompt para generar imágenes:_
#
# Genera un personaje caricaturesco de {personaje}, en estilo {estilo},
# colorido y amigable, pensado para un niño de {edad} años.
# El personaje debe estar contextualizado en base a la siguiente pregunta educativa:
# '{pregunta}'.
#
# Por ejemplo:
#
# Genera un personaje caricaturesco de un dragón amistoso, en estilo cartoon,
# colorido y amigable, pensado para un niño de 12 años.
# El contexto del personaje debe estar contextualizado en base a la siguiente pregunta educativa:
# '{pregunta obtenida en el prompt de generación de multiple choice}'.

# %%
from google import genai
from google.genai import types
import PIL.Image
from io import BytesIO
import json

client = genai.Client(api_key=mi_api_key)

'''
Variables del prompt
'''
tema=input("Ingrese el tema de la lección (Ej.: Fracciones): ")
ambientacion=input("Ingrese la ambientación de la misión (Ej.: Exploradores espaciales donde los niños deben repartir provisiones en partes iguales entre planetas): ")
edad=int(input("Ingrese la edad del niño a quien está dirigido (Ej.: 12): "))
tono=input("Ingrese el tono en el cual va a responder la IA a la respuesta ingresada (Ej.: Motivador): ")

# PROMPT
prompt = f"""
Convierte esta lección sobre {tema} en una misión interactiva estilo {ambientacion}. 
La historia debe estar dirigida a un niño de {edad} años con TDAH. 
Incluye preguntas de opción múltiple, respuestas con feedback positivo, y un tono {tono}. 

Devuelve la respuesta en JSON válido con el siguiente formato:

{{
  "historia": "texto breve con la narrativa gamificada",
  "preguntas": [
    {{
      "pregunta": "string",
      "opciones": ["string", "string", "string"],
      "respuesta_correcta": "string",
      "feedback": {{
        "correcto": "string",
        "incorrecto": "string"
      }}
    }}
  ]
}}
"""

response = client.models.generate_content(
    model = "gemini-2.5-flash",
    contents = prompt,
    config = types.GenerateContentConfig(
        thinking_config=types.ThinkingConfig(thinking_budget=0) # Desabilita el "Pensar" para dar respuestas mas rápidas y disminuir el tiempo de ejecución.
    ),
)

print(response.text)

# Me quedo solo con el json y lo convierto.

limpio = response.text.strip("`")
limpio = limpio.replace("json\n","",1)

cuestionario=json.loads(limpio)

##########################
#                        #
# Generación de imágenes #
#                        #
##########################

personaje=input("Ingrese un personaje: ")
estilo=input("Ingrese un estilo de dibujo: ")
pregunta=cuestionario["preguntas"][0]["pregunta"]

image_prompt=f"""Genera una imagen de un personaje caricaturesco de {personaje}, en estilo {estilo}, 
colorido y amigable, pensado para un niño de {edad} años. 
El personaje debe estar contextualizado en base a la siguiente pregunta educativa: 
'{pregunta}'."""

image_response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=[image_prompt],
)

for part in image_response.candidates[0].content.parts:
  if part.text is not None:
    print(part.text)
  if part.inline_data is not None:
    image = PIL.Image.open(BytesIO(part.inline_data.data))
    image.show()
# Out:
# ```json
# {
#   "historia": "¡Atención, cadete espacial! Soy el Comandante Nova, y tengo una misión urgente para ti. Nuestra nave, el 'Explorador Fraccional', ha sido golpeada por una tormenta de asteroides y ahora está dispersa por el Sector Numérico. ¡Necesitamos que recuperes las 'Unidades Completas' y las 'Partes Especiales' para reconstruirla! Tu nave, la 'Mochila Cósmica', te ayudará a recolectar estos valiosos componentes, pero solo si entiendes cómo funcionan las fracciones. Cada respuesta correcta te acerca a tu objetivo. ¿Listo para ser el héroe del espacio que necesitamos? ¡Vamos a ello!",
#   "preguntas": [
#     {
#       "pregunta": "Para empezar, la nave 'Mochila Cósmica' tiene un nuevo sistema de energía. Necesitamos saber qué es una 'unidad completa'. Imagina una pizza entera para toda la tripulación. ¿Qué representa esa pizza completa en términos de fracciones?",
#       "opciones": ["Una parte de algo", "Todo el objeto", "Dos objetos juntos"],
#       "respuesta_correcta": "Todo el objeto",
#       "feedback": {
#         "correcto": "¡Excelente, cadete! ¡Lo has captado! Una unidad completa es como esa pizza entera, no falta nada. ¡Tu 'Mochila Cósmica' ha cargado un 100% de energía inicial!",
#         "incorrecto": "Casi lo tienes, cadete. Recuerda, una 'unidad completa' significa que no le falta nada. Piensa en la pizza: cuando está entera, es una unidad completa. ¡Inténtalo de nuevo, sé que puedes!"
#       }
#     },
#     {
#       "pregunta": "¡Perfecto! Ahora la nave necesita una pieza. El ingeniero dice: 'Necesitamos 1/2 de la aleación de titanio'. ¿Qué significa '1/2'?",
#       "opciones": ["Una pieza de dos iguales", "Dos piezas iguales", "La mitad de dos piezas"],
#       "respuesta_correcta": "Una pieza de dos iguales",
#       "feedback": {
#         "correcto": "¡Increíble, cadete! ¡Has identificado la pieza de aleación correcta! '1/2' significa que de dos partes iguales, tomamos una. ¡La 'Mochila Cósmica' ha recogido el primer componente crítico!",
#         "incorrecto": "No te rindas, cadete. Piensa en esa pizza otra vez. Si la cortas por la mitad, cada parte es 1/2 del total. ¡Eso significa una de dos partes iguales! ¡Inténtalo de nuevo!"
#       }
#     },
#     {
#       "pregunta": "Hemos encontrado un cargamento de cristales energéticos. El informe indica que 3/4 de los cristales son azules. ¿Qué significa el número '4' en la fracción 3/4?",
#       "opciones": ["Las partes que tenemos", "El número total de partes iguales en que se divide el objeto", "Cuántos objetos hay en total"],
#       "respuesta_correcta": "El número total de partes iguales en que se divide el objeto",
#       "feedback": {
#         "correcto": "¡Asombroso, cadete! ¡Has identificado correctamente el número total de divisiones! El '4' nos dice en cuántas partes iguales se dividió el cargamento. ¡Los cristales azules están a salvo!",
#         "incorrecto": "Estás cerca, cadete. Recuerda que el número de abajo en una fracción, el denominador, siempre nos dice cuántas partes iguales tiene el todo. ¡Piensa en la pizza dividida en 4 trozos! ¡Dale otra oportunidad!"
#       }
#     },
#     {
#       "pregunta": "¡Excelente trabajo! Ahora, el Navegador Estelar necesita 2/3 de un mapa galáctico para encontrar el siguiente punto de control. ¿Qué significa el número '2' en la fracción 2/3?",
#       "opciones": ["Las partes que se dividieron", "Las partes que se están considerando o utilizando", "El total de mapas galácticos"],
#       "respuesta_correcta": "Las partes que se están considerando o utilizando",
#       "feedback": {
#         "correcto": "¡Magnífico, cadete! ¡Has interpretado perfectamente el mapa! El '2' nos indica cuántas de esas tres partes iguales del mapa estamos utilizando. ¡Rumbo al siguiente punto de control!",
#         "incorrecto": "Ánimo, cadete. El número de arriba en una fracción, el numerador, nos dice cuántas partes estamos usando o de cuántas estamos hablando. ¡Si tienes un pastel dividido en 3 y tomas 2 trozos, estás tomando 2/3! ¡Lo tienes!"
#       }
#     },
#     {
#       "pregunta": "¡Casi hemos llegado! Solo nos falta una última 'Unidad Completa'. Tenemos un tanque de combustible que está 5/5 lleno. ¿Qué significa esto en términos de una unidad completa?",
#       "opciones": ["El tanque está vacío", "El tanque está a la mitad", "El tanque está completamente lleno"],
#       "respuesta_correcta": "El tanque está completamente lleno",
#       "feedback": {
#         "correcto": "¡Misión cumplida, Comandante! ¡Eres una estrella! Cuando el numerador y el denominador son iguales, como 5/5, ¡significa que tenemos la unidad completa! ¡El tanque está lleno y la nave 'Explorador Fraccional' está lista para volver a casa!",
#         "incorrecto": "¡No te desanimes, cadete! Recuerda que si tienes todas las partes del todo, entonces tienes una unidad completa. Si tienes 5 de 5 trozos de pizza, ¡tienes la pizza entera! ¡Un último intento!"
#       }
#     }
#   ]
# }
# ```
# ¡Claro! Aquí tienes una descripción detallada para generar esa imagen:
#
# **Descripción de la imagen:**
#
# Genera una imagen de un personaje de dinosaurio caricaturesco y amigable, en un estilo cartoon vibrante y colorido, ideal para un niño de 12 años.
#
# El dinosaurio tiene una gran sonrisa cálida y ojos grandes y expresivos que transmiten inteligencia y amabilidad. Su piel es de un verde brillante y tiene manchas o patrones de colores como el azul y el naranja. No es intimidante en absoluto, sino más bien como un mentor divertido.
#
# Está orgullosamente presentando una pizza entera y perfectamente **completa**, deliciosa y recién hecha, que se ve intacta y sin cortar, sobre una bandeja de servir redonda. La pizza tiene ingredientes clásicos y coloridos como pepperoni, pimientos, champiñones y mucho queso derretido, haciendo que se vea apetitosa.
#
# El dinosaurio gesticula hacia la pizza con una de sus manos (o una garra amigable), como si estuviera explicando con entusiasmo el concepto de una "unidad completa". Su postura es dinámica y acogedora, invitando al espectador a entender la lección.
#
# El fondo es brillante y limpio, con sutiles toques cósmicos como algunas estrellas distantes, un pequeño planeta estilizado o una luna caricaturesca en el horizonte, insinuando la temática espacial de la "Mochila Cósmica" sin distraer del personaje principal y la pizza. La iluminación es suave y alegre.
